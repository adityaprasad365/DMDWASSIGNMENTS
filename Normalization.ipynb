# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import statistics as st

# %%
df = pd.read_csv('ToyotaCorolla.csv')

# %%
df.shape
# Out:
# (1435, 9)

# %%
df.head()
# Out:
#    Age     KM Fuel_Type  HP  Automatic    CC  Quarterly_Tax  Weight  Price
# 0   23  46986    Diesel  90          0  2000            210    1165  13500
# 1   23  72937    Diesel  90          0  2000            210    1165  13750
# 2   24  41711    Diesel  90          0  2000            210    1165  13950
# 3   26  48000    Diesel  90          0  2000            210    1165  14950
# 4   30  38500    Diesel  90          0  2000            210    1170  13750

# %%
df.sample(10)
# Out:
#       Age      KM Fuel_Type   HP  Automatic    CC  Quarterly_Tax  Weight  \
# 744    68   81965    Petrol   86          0  1300             69    1035
# 375    39   12000    Petrol  110          0  1600             85    1075
# 783    61   75609    Petrol   86          0  1300             69    1015
# 1088   77  128960    Petrol  110          0  1600             85    1070
# 785    67   75429    Petrol  110          0  1600             85    1065
# 541    52   46029    Petrol  110          0  1600             69    1030
# 207    41   84312    Petrol  110          0  1600             85    1080
# 1017   57   35000    Petrol   86          0  1300             69    1045
# 367    37   21500    Petrol  110          0  1600             69    1030
# 639    68  119541    Petrol  110          0  1600             85    1055
#
#       Price
# 744    8450
# 375   11500
# 783    8950
# 1088   7250
# 785    9950
# 541   10500
# 207   11450
# 1017  10900
# 367   11450
# 639    9950

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1435 entries, 0 to 1434
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            1435 non-null   int64
#  1   KM             1435 non-null   int64
#  2   Fuel_Type      1435 non-null   object
#  3   HP             1435 non-null   int64
#  4   Automatic      1435 non-null   int64
#  5   CC             1435 non-null   int64
#  6   Quarterly_Tax  1435 non-null   int64
#  7   Weight         1435 non-null   int64
#  8   Price          1435 non-null   int64
# dtypes: int64(8), object(1)
# memory usage: 101.0+ KB

# %%
df.dtypes
# Out:
# Age               int64
# KM                int64
# Fuel_Type        object
# HP                int64
# Automatic         int64
# CC                int64
# Quarterly_Tax     int64
# Weight            int64
# Price             int64
# dtype: object

# %%
df.describe()
# Out:
#                Age             KM           HP    Automatic           CC  \
# count  1435.000000    1435.000000  1435.000000  1435.000000  1435.000000
# mean     55.968641   68567.067596   101.496167     0.055052  1566.804878
# std      18.588504   37497.629827    14.984621     0.228162   187.245640
# min       1.000000       1.000000    69.000000     0.000000  1300.000000
# 25%      44.000000   43000.000000    90.000000     0.000000  1400.000000
# 50%      61.000000   63451.000000   110.000000     0.000000  1600.000000
# 75%      70.000000   87041.500000   110.000000     0.000000  1600.000000
# max      80.000000  243000.000000   192.000000     1.000000  2000.000000
#
#        Quarterly_Tax       Weight         Price
# count    1435.000000  1435.000000   1435.000000
# mean       87.113589  1072.384669  10725.096864
# std        41.141543    52.582788   3621.726584
# min        19.000000  1000.000000   4350.000000
# 25%        69.000000  1040.000000   8450.000000
# ...

# %%
df.describe(include='all')
# Out:
#                 Age             KM Fuel_Type           HP    Automatic  \
# count   1435.000000    1435.000000      1435  1435.000000  1435.000000
# unique          NaN            NaN         3          NaN          NaN
# top             NaN            NaN    Petrol          NaN          NaN
# freq            NaN            NaN      1263          NaN          NaN
# mean      55.968641   68567.067596       NaN   101.496167     0.055052
# std       18.588504   37497.629827       NaN    14.984621     0.228162
# min        1.000000       1.000000       NaN    69.000000     0.000000
# 25%       44.000000   43000.000000       NaN    90.000000     0.000000
# 50%       61.000000   63451.000000       NaN   110.000000     0.000000
# 75%       70.000000   87041.500000       NaN   110.000000     0.000000
# max       80.000000  243000.000000       NaN   192.000000     1.000000
#
#                  CC  Quarterly_Tax       Weight         Price
# ...

# %%
df.isnull().sum()
# Out:
# Age              0
# KM               0
# Fuel_Type        0
# HP               0
# Automatic        0
# CC               0
# Quarterly_Tax    0
# Weight           0
# Price            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df = df.select_dtypes(exclude=['object'])

# %% [markdown]
# ### MIN-MAX NORMALIZATION

# %%
df_min_max = df.copy()

# max-min normalization techniques
for column in df_min_max.columns:
	df_min_max[column] = (df_min_max[column] - df_min_max[column].min()) / (df_min_max[column].max() - df_min_max[column].min())

print(df_min_max)
# Out:
#            Age        KM        HP  Automatic        CC  Quarterly_Tax  \
# 0     0.278481  0.193355  0.170732        0.0  1.000000       0.723485
# 1     0.278481  0.300149  0.170732        0.0  1.000000       0.723485
# 2     0.291139  0.171647  0.170732        0.0  1.000000       0.723485
# 3     0.316456  0.197528  0.170732        0.0  1.000000       0.723485
# 4     0.367089  0.158433  0.170732        0.0  1.000000       0.723485
# ...        ...       ...       ...        ...       ...            ...
# 1430  0.860759  0.084539  0.138211        0.0  0.000000       0.189394
# 1431  0.898734  0.078186  0.138211        0.0  0.000000       0.189394
# 1432  0.886076  0.070021  0.138211        0.0  0.000000       0.189394
# 1433  0.873418  0.069609  0.138211        0.0  0.000000       0.189394
# 1434  0.949367  0.000000  0.333333        0.0  0.428571       0.000000
#
#         Weight     Price
# 0     0.268293  0.325044
# 1     0.268293  0.333925
# 2     0.268293  0.341030
# ...

# %% [markdown]
# ### Z-SCORE TECHNIQUES

# %%
df_z_score = df.copy()

# z-score normalization techniques
for column in df_z_score.columns:
	df_z_score[column] = (df_z_score[column] - df_z_score[column].mean()) / df_z_score[column].std()

display(df_z_score)
# Out:
#            Age        KM        HP  Automatic        CC  Quarterly_Tax  \
# 0    -1.773604 -0.575532 -0.767198  -0.241286  2.313512       2.986918
# 1    -1.773604  0.116539 -0.767198  -0.241286  2.313512       2.986918
# 2    -1.719807 -0.716207 -0.767198  -0.241286  2.313512       2.986918
# 3    -1.612214 -0.548490 -0.767198  -0.241286  2.313512       2.986918
# 4    -1.397027 -0.801839 -0.767198  -0.241286  2.313512       2.986918
# ...        ...       ...       ...        ...       ...            ...
# 1430  0.701044 -1.280696 -1.034138  -0.241286 -1.424892      -0.440275
# 1431  0.862434 -1.321872 -1.034138  -0.241286 -1.424892      -0.440275
# 1432  0.808637 -1.374782 -1.034138  -0.241286 -1.424892      -0.440275
# 1433  0.754841 -1.377449 -1.034138  -0.241286 -1.424892      -0.440275
# 1434  1.077621 -1.828544  0.567504  -0.241286  0.177281      -1.655591
#
#         Weight     Price
# 0     1.761324  0.766182
# 1     1.761324  0.835210
# 2     1.761324  0.890433
# ...

# %% [markdown]
# ### Decimal Scaling

# %%
df['Age_Decimal'] = df['Age_08_04']/100
df['price_decimal'] = df['Price']/100
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age_08_04'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.head()
